# %%
import  canopus
from qiskit.transpiler import CouplingMap

# %%
CouplingMap([(0,1), (1, 6)]).draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=299x323>

# %%
map = canopus.utils.gene_square_coupling_map(9)

# %%
map.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=335x311>

# %%
map.graph.edge_index_map()
