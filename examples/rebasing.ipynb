# %%
from scipy.stats import unitary_group
import canopus
from qiskit.quantum_info import Operator
import numpy as np
from qiskit.circuit.random import random_circuit

# %% [markdown]
# ### B gate optimal decomposition and ISA rebase

# %%
# target requires 0 B gates
u = np.kron(unitary_group.rvs(2), unitary_group.rvs(2))
qc = canopus.decomposition.two_qubit_unitary_to_b_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
# global phase: 0.30454
#      ┌────────────────────────────┐
# q_0: ┤ U(1.8163,-0.61298,0.78389) ├
#      ├────────────────────────────┤
# q_1: ┤ U(2.2694,-2.6329,0.094726) ├
#      └────────────────────────────┘

# %%
# target requires 1 B gates
u = canopus.BGate().to_matrix()
qc = canopus.decomposition.two_qubit_unitary_to_b_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
#      ┌──────────┐┌────┐┌──────────┐
# q_0: ┤ U(0,π,π) ├┤0   ├┤ U(0,π,π) ├
#      ├──────────┤│  B │├──────────┤
# q_1: ┤ U(0,0,0) ├┤1   ├┤ U(0,0,0) ├
#      └──────────┘└────┘└──────────┘

# %%
# target requires 2 B gates
u = unitary_group.rvs(4)
qc = canopus.decomposition.two_qubit_unitary_to_b_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
# global phase: 2.5113
#      ┌────────────────────────────┐┌────┐ ┌────────────┐                              ┌────┐┌────────────────────────────┐
# q_0: ┤ U(2.5096,-1.0695,-0.29636) ├┤0   ├─┤ Ry(1.4882) ├──────────────────────────────┤0   ├┤ U(2.3726,-0.42026,-3.1356) ├
#      ├───────────────────────────┬┘│  B │┌┴────────────┤┌─────────────┐┌─────────────┐│  B │└┬──────────────────────────┬┘
# q_1: ┤ U(2.1195,-2.0932,-2.6195) ├─┤1   ├┤ Rz(-1.5054) ├┤ Ry(-1.4109) ├┤ Rz(-1.5054) ├┤1   ├─┤ U(2.5194,1.3701,-4.0288) ├─
#      └───────────────────────────┘ └────┘└─────────────┘└─────────────┘└─────────────┘└────┘ └──────────────────────────┘

# %%
qc = random_circuit(5, 100, max_operands=2)
qc_b = canopus.rebase_to_b(qc)
# assert Operator(qc_b).equiv(qc)
print('infidelity:', canopus.utils.infidelity(canopus.utils.qc2mat(qc), canopus.utils.qc2mat(qc_b)))
qc_b.draw(fold=-1)
# Out:
# infidelity: -2.6645352591003757e-15
# global phase: 4.891
# ...

# %% [markdown]
# ### √iSWAP gate optimal decomposition and ISA rebase

# %%
def sandwich_single_qubit_unitaries(u):
    return np.kron(unitary_group.rvs(2), unitary_group.rvs(2)) @ u @ np.kron(unitary_group.rvs(2), unitary_group.rvs(2))

u = unitary_group.rvs(4)

# %%
# target requires 0 √iSWAP gates
u = sandwich_single_qubit_unitaries(np.identity(4))
qc = canopus.decomposition.two_qubit_unitary_to_sqisw_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
# global phase: 5.4986
#      ┌────────────────────────────┐
# q_0: ┤ U(1.7476,-5.1617,-0.21414) ├
#      └┬──────────────────────────┬┘
# q_1: ─┤ U(0.99839,2.443,-2.7006) ├─
#       └──────────────────────────┘

# %%
# target requires 1 √iSWAP gates
u = sandwich_single_qubit_unitaries(canopus.CanonicalGate(0.25, 0.25, 0).to_matrix())
qc = canopus.decomposition.two_qubit_unitary_to_sqisw_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
# global phase: 1.173
#       ┌──────────────────────────┐┌────────┐┌────────────────────────────┐
# q_0: ─┤ U(1.3699,-4.4602,1.7422) ├┤0       ├┤ U(2.2126,1.2037,-0.041398) ├
#      ┌┴──────────────────────────┤│  Sqisw │└┬──────────────────────────┬┘
# q_1: ┤ U(0.49487,2.2564,-1.7773) ├┤1       ├─┤ U(2.6082,3.2096,0.55911) ├─
#      └───────────────────────────┘└────────┘ └──────────────────────────┘

# %%
# target requires 2 √iSWAP gates
u = sandwich_single_qubit_unitaries(canopus.CanonicalGate(0.4, 0.3, 0).to_matrix())
qc = canopus.decomposition.two_qubit_unitary_to_sqisw_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
# global phase: 1.7021
#      ┌───────────────────────────┐┌────────┐┌────────────────────────┐┌────────┐┌───────────────────────────┐
# q_0: ┤ U(1.1674,-1.4368,0.79639) ├┤0       ├┤ U(0,-0.52572,-0.52572) ├┤0       ├┤ U(2.8273,0.29565,-2.3314) ├
#      └┬──────────────────────────┤│  Sqisw │└─┬────────────────────┬─┘│  Sqisw │└┬─────────────────────────┬┘
# q_1: ─┤ U(1.1454,3.5436,-2.2648) ├┤1       ├──┤ U(1.1125,π/2,-π/2) ├──┤1       ├─┤ U(2.2559,2.2605,1.9891) ├─
#       └──────────────────────────┘└────────┘  └────────────────────┘  └────────┘ └─────────────────────────┘

# %%
# target requires 3 √iSWAP gates
u = sandwich_single_qubit_unitaries(canopus.CanonicalGate(0.5, 0.3, 0.25).to_matrix())
qc = canopus.decomposition.two_qubit_unitary_to_sqisw_circuit(u)
assert Operator(qc).reverse_qargs().equiv(u)
qc.draw(fold=-1)
# Out:
# global phase: 3.6443
#      ┌────────────────────────────┐┌────────┐    ┌───────────────────┐     ┌────────┐┌──────────────────────────────┐┌────────┐ ┌──────────────────────────┐
# q_0: ┤ U(0.67683,-1.3196,-3.4114) ├┤0       ├────┤ U(π/2,3.1416,π/2) ├─────┤0       ├┤ U(0,-6.9893e-08,-6.9893e-08) ├┤0       ├─┤ U(2.1256,-1.1222,-1.743) ├
#      └┬─────────────────────────┬─┘│  Sqisw │┌───┴───────────────────┴────┐│  Sqisw │└────┬────────────────────┬────┘│  Sqisw │┌┴──────────────────────────┤
# q_1: ─┤ U(1.7829,2.3954,2.0423) ├──┤1       ├┤ U(1.5708,-3.1416,0.078783) ├┤1       ├─────┤ U(2.9192,π/2,-π/2) ├─────┤1       ├┤ U(0.28089,-3.0479,1.1688) ├
#       └─────────────────────────┘  └────────┘└────────────────────────────┘└────────┘     └────────────────────┘     └────────┘└───────────────────────────┘

# %%
# end-to-end circuit rebase
qc = random_circuit(5, 30, max_operands=2)
qc_sqisw = canopus.rebase_to_sqisw(qc)
assert Operator(qc_sqisw).equiv(qc)
qc_sqisw.draw(fold=-1)
# Out:
# global phase: 2.3336
#      ┌────────────────────────────┐┌────────┐┌────────────────────┐┌────────┐ ┌──────────────────────────┐┌────────┐┌────────────────────┐┌────────┐┌───────────────────────────┐
# q_0: ┤ U(1.5339,-0.15642,-2.0656) ├┤1       ├┤ U(3.1416,π/2,-π/2) ├┤1       ├─┤ U(1.7556,3.0796,-2.6088) ├┤1       ├┤ U(1.7079,π/2,-π/2) ├┤1       ├┤ U(1.6101,-3.7989,0.10373) ├
#      ├───────────────────────────┬┘│        │└────────────────────┘│        │ └──────────────────────────┘│        │└────────────────────┘│        │└───────────────────────────┘
# q_1: ┤ U(2.6495,0.43666,0.23512) ├─┤        ├──────────────────────┤        ├─────────────────────────────┤        ├──────────────────────┤        ├─────────────────────────────
#      ├───────────────────────────┴┐│  Sqisw │                      │  Sqisw │                             │        │                      │        │
# ...

# %% [markdown]
# ### Rebase to Canonical

# %%
qc = random_circuit(4, 50, max_operands=2)
qc_can = canopus.rebase_to_canonical(qc)
assert Operator(qc_can).equiv(qc)
qc_can.draw(fold=-1)
# Out:
# global phase: 0.96095
# ...

# %%
canopus.utils.print_circ_info(qc_can)
# Out:
# +------------+-----------+--------------+-------+----------+
# | num_qubits | num_gates | num_2q_gates | depth | depth_2q |
# +------------+-----------+--------------+-------+----------+
# |     4      |    199    |      65      |   69  |    34    |
# +------------+-----------+--------------+-------+----------+

# %% [markdown]
# ### Rebase to ZZPhase ISA

# %%
qc = random_circuit(4, 50, max_operands=2)
qc_zz = canopus.rebase_to_zzphase(qc)
assert Operator(qc_zz).equiv(qc)
qc_zz.draw(fold=-1)
# Out:
# global phase: 2.2989
# ...

# %% [markdown]
# ### Rebase to Customized ISA

# %%
# ! You can use any arbitrary ISA and basis-gate-specific cost setting
# ! Approximate synthesis method is utilized to achieve numerically-exact, optimal rebasing
gate_set = [canopus.CanonicalGate(0.25, 0, 0), canopus.CanonicalGate(0.5, 0.3, 0)]
qc = random_circuit(4, 15, max_operands=2)
qc_custom = canopus.rebase_to_custom(qc, gate_set=gate_set, costs=[0.8, 1.0], names=['g1', 'g2'])

# %%
assert Operator(qc_custom).equiv(qc)
qc_custom.draw(fold=-1)
# Out:
# global phase: 0.17425
#       ┌─────────────────────────┐ ┌────────────────┐┌─────────────────────────┐┌────────────────┐ ┌─────────────────────────┐                   ┌────────────────┐  ┌─────────────────────┐  ┌────────────────┐ ┌────────────────────────┐
# q_0: ─┤ U(1.5708,4.7124,1.4667) ├─┤0               ├┤ U(3.1416,2.7089,2.7089) ├┤0               ├─┤ U(2.826,1.5709,-1.5707) ├───────────────────┤0               ├──┤ U(3π,2.4417,5.5833) ├──┤0               ├─┤ U(2.6649,3.0766,6.457) ├─
#       └┬────────────────────────┤ │  Can(0.25,0,0) │├─────────────────────────┤│  Can(0.25,0,0) │┌┴─────────────────────────┴┐┌────────────────┐│                │┌─┴─────────────────────┴─┐│                │ └────────────────────────┘
# q_1: ──┤ U(2.011,8.5884,5.2135) ├─┤1               ├┤ U(4.7051,4.7124,4.7124) ├┤1               ├┤ U(1.6206,-0.34008,1.3632) ├┤0               ├┤                ├┤ U(5.5883,1.4126,3.1409) ├┤                ├────────────────────────────
# ...

# %%
canopus.utils.print_circ_info(qc_custom)
# Out:
# +------------+-----------+--------------+-------+----------+
# | num_qubits | num_gates | num_2q_gates | depth | depth_2q |
# +------------+-----------+--------------+-------+----------+
# |     4      |     19    |      5       |   9   |    4     |
# +------------+-----------+--------------+-------+----------+
